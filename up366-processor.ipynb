# %%
# !git clone https://github.com/wangdog114/up366.git

# %%
-whisper nemo-toolkit[asr] #Ignore errors

# %%
cd up366/project

# %%
# !python main.py

# %%
# !tar -cJvf /kaggle/working/up366/output.tar.xz /kaggle/working/up366/output
